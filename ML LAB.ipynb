# %%
 import numpy as np
 import pandas as pd
 import matplotlib.pyplot as plt
 import seaborn as sns
 file_path = r"D:\EXCELWORKS\5AI REGULAR.xls" 
 df = pd.read_excel(file_path,header=4)
 print("Available columns:\n",df.columns)
# Out:
# Available columns:
#  Index(['Sl. No', 'Name', 'USN', 'Internal', 'External', 'Total', 'Result',
#        'Internal.1', 'External.1', 'Total.1', 'Result.1', 'Internal.2',
#        'External.2', 'Total.2', 'Result.2', 'Internal.3', 'External.3',
#        'Total.3', 'Result.3', 'Internal.4', 'External.4', 'Total.4',
#        'Result.4', 'Internal.5', 'External.5', 'Total.5', 'Result.5',
#        'Internal.6', 'External.6', 'Total.6', 'Result.6', 'Internal.7',
#        'External.7', 'Total.7', 'Result.7', 'Internal.8', 'External.8',
#        'Total.8', 'Result.8', 'Internal.9', 'External.9', 'Total.9',
#        'Result.9', 'Final Total', 'Final Result'],
#       dtype='object')

# %%
# !pip install xlrd
# Out:
# ...
#   Using cached xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Using cached xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

file_path = r"D:\EXCELWORKS\5AI REGULAR.xls"
df = pd.read_excel(file_path, header=4)

column1 = "Internal.3"
column2 = "External.3"
selected_data = df[[column1, column2]]

plt.figure(figsize=(8, 6))
plt.scatter(selected_data[column1], selected_data[column2], color="blue", alpha=0.7)
plt.title(f"Scatter Plot of {column1} vs {column2}")
plt.xlabel(column1)
plt.ylabel(column2)
plt.grid(True)
plt.show()

correlation_coefficient = np.corrcoef(selected_data[column1], selected_data[column2])[0, 1]
print(f"Pearson Correlation Coefficient ({column1} vs {column2}): {correlation_coefficient:.2f}")

cov_matrix = np.cov(selected_data[column1], selected_data[column2])
print("\nCovariance Matrix:")
print(cov_matrix)

correlation_matrix = selected_data.corr()
print("\nCorrelation Matrix:")
print(correlation_matrix)

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', vmin=-1, vmax=1)
plt.title("Correlation Matrix Heatmap")
plt.show()
# Out:
# Pearson Correlation Coefficient (Internal.3 vs External.3): nan
#
# Covariance Matrix:
# [[nan nan]
#  [nan nan]]
#
# Correlation Matrix:
#             Internal.3  External.3
# Internal.3      1.0000      0.3977
# External.3      0.3977      1.0000

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


file_path = r"D:\EXCELWORKS\5AI REGULAR.xls"
df = pd.read_excel(file_path, header=4)


internal_cols = [col for col in df.columns if 'Internal' in col]
external_cols = [col for col in df.columns if 'External' in col]


df['Total_Internal'] = df[internal_cols].sum(axis=1)
df['Total_External'] = df[external_cols].sum(axis=1)


plt.figure(figsize=(8, 6))
plt.scatter(df['Total_Internal'], df['Total_External'], color="green", alpha=0.7)
plt.title("Scatter Plot of Total Internal vs Total External Marks")
plt.xlabel("Total Internal Marks")
plt.ylabel("Total External Marks")
plt.grid(True)
plt.show()


correlation_coefficient = np.corrcoef(df['Total_Internal'], df['Total_External'])[0, 1]
print(f"Pearson Correlation Coefficient (Total Internal vs Total External): {correlation_coefficient:.2f}")


cov_matrix = np.cov(df['Total_Internal'], df['Total_External'])
print("\nCovariance Matrix:")
print(cov_matrix)


correlation_matrix = df[['Total_Internal', 'Total_External']].corr()
print("\nCorrelation Matrix:")
print(correlation_matrix)


plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", cbar=True)
plt.title("Correlation Matrix Heatmap (Total Marks)")
plt.show()
# Out:
# Pearson Correlation Coefficient (Total Internal vs Total External): 0.44
#
# Covariance Matrix:
# [[18080.08332793  4436.32583946]
#  [ 4436.32583946  5520.0428007 ]]
#
# Correlation Matrix:
#                 Total_Internal  Total_External
# Total_Internal        1.000000        0.444071
# Total_External        0.444071        1.000000
